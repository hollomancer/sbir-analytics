# %% [markdown]
# # Getting Started with SBIR Analytics
#
# This notebook demonstrates how to load the SBIR Analytics environment and access key components.

# %%
import os
import sys
from pathlib import Path

# Add src to path for imports
project_root = Path("..").resolve()
sys.path.append(str(project_root))

from src.config import load_config
from src.utils.logging import setup_logging

# Initialize environment
setup_logging()
config = load_config()

print(f"Loaded configuration for environment: {config.pipeline.environment}")

# %% [markdown]
# ## Fiscal Analysis Example
#
# Load the fiscal analysis module and run a simple calculation.

# %%
# Example placeholder for Fiscal Analysis
# from src.analysis.fiscal import FiscalAnalyzer
# analyzer = FiscalAnalyzer(config)
# results = analyzer.analyze_impact(award_amount=150000, year=2023)
# print(results)

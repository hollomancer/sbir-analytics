# %% [markdown]
# # Getting Started with SBIR Analytics (Cloud-Native)
#
# This notebook demonstrates how to load the SBIR Analytics environment and access key components using **Cloud Resources**.
#
# **Prerequisites:**
# 1. Run `make setup-ml` to configure `.env` for S3 and HuggingFace.
# 2. Ensure you have valid AWS credentials and an HF Token.

# %%
import sys
import os
from pathlib import Path

# Change to project root directory
project_root = Path("..").resolve()
os.chdir(project_root)
sys.path.append(str(project_root))

from src.config import load_config
from src.utils.logging import setup_logging

# Initialize environment
setup_logging()
config = load_config()

print(f"Loaded configuration for environment: {config.pipeline.get('environment', 'unknown')}")
print(f"Configuration loaded successfully")
# Out:
# Loaded configuration for environment: development
# Configuration loaded successfully

# %% [markdown]
# ## Fiscal Analysis Example
#
# Load the fiscal analysis module. This may require R dependencies.

# %%
# Example placeholder for Fiscal Analysis
# from src.analysis.fiscal import FiscalAnalyzer
# analyzer = FiscalAnalyzer(config)
# results = analyzer.analyze_impact(award_amount=150000, year=2023)
# print(results)

# %% [markdown]
# ## CET Classification (HuggingFace)
#
# Load the CET classifier. This requires `HF_TOKEN` to be set.

# %%
# from src.enrichers.cet_classifier import CETClassifier
# classifier = CETClassifier()
# print("Classifier loaded successfully")
